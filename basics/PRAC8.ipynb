# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import os

# %%
spark = SparkSession.builder\
    .appName("Practice")\
    .master("local[*]")\
    .getOrCreate()

# %% [markdown]
# READ MODE

# %%
file_path = "/home/somnath/my_vscode_project/input_data/MOCK_DATA.csv"
path = "/home/somnath/my_vscode_project/output_data/"

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .option("mode", "PERMISSIVE") \
    .option("inferSchema", "true") \
    .load(file_path)

# %% [markdown]
# WRITE MODE with coalesce

# %%
df.coalesce(1).write.format("CSV") \
    .option("header", "true") \
    .mode("overwrite") \
    .save(path)

# %%
os.listdir(path)
# Out:
# ['_SUCCESS',
#  '._SUCCESS.crc',
#  'part-00000-9788b05e-6337-4627-b11a-e680e5d25fd1-c000.csv',
#  '.part-00000-9788b05e-6337-4627-b11a-e680e5d25fd1-c000.csv.crc']

# %%
spark.stop()
