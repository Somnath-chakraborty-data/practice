# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import os

# %%
spark = SparkSession.builder.appName("Basics").master("local[*]").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/02/07 05:49:43 WARN Utils: Your hostname, Somnath, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/02/07 05:49:43 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/07 05:49:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
data=[(10 ,'Anil',50000, 18),
(11 ,'Vikas',75000,  16),
(12 ,'Nisha',40000,  18),
(13 ,'Nidhi',60000,  17),
(14 ,'Priya',80000,  18),
(15 ,'Mohit',45000,  18),
(16 ,'Rajesh',90000, 10),
(17 ,'Raman',55000, 16),
(18 ,'Sam',65000,   17),
(17 ,'Raman',55000, 16),
(17 ,'Raman',59000, 16)]

# %%
schema =['id','name','salary','manager_id']

# %%
df = spark.createDataFrame(data,schema)

# %%
data1=[(19 ,'Sohan',50000, 18),
(20 ,'Sima',75000,  17)]

# %%
schema =['id','name','salary','manager_id']

# %%
df1 = spark.createDataFrame(data1,schema)

# %%
df1.show()
# Out:
# +---+-----+------+----------+
# | id| name|salary|manager_id|
# +---+-----+------+----------+
# | 19|Sohan| 50000|        18|
# | 20| Sima| 75000|        17|
# +---+-----+------+----------+

# %%
df.show()
# Out:
# +---+------+------+----------+
# | id|  name|salary|manager_id|
# +---+------+------+----------+
# | 10|  Anil| 50000|        18|
# | 11| Vikas| 75000|        16|
# | 12| Nisha| 40000|        18|
# | 13| Nidhi| 60000|        17|
# | 14| Priya| 80000|        18|
# | 15| Mohit| 45000|        18|
# | 16|Rajesh| 90000|        10|
# | 17| Raman| 55000|        16|
# | 18|   Sam| 65000|        17|
# | 17| Raman| 55000|        16|
# | 17| Raman| 59000|        16|
# +---+------+------+----------+

# %%
df.union(df1).show()
# Out:
# +---+------+------+----------+
# | id|  name|salary|manager_id|
# +---+------+------+----------+
# | 10|  Anil| 50000|        18|
# | 11| Vikas| 75000|        16|
# | 12| Nisha| 40000|        18|
# | 13| Nidhi| 60000|        17|
# | 14| Priya| 80000|        18|
# | 15| Mohit| 45000|        18|
# | 16|Rajesh| 90000|        10|
# | 17| Raman| 55000|        16|
# | 18|   Sam| 65000|        17|
# | 17| Raman| 55000|        16|
# | 17| Raman| 59000|        16|
# | 19| Sohan| 50000|        18|
# | 20|  Sima| 75000|        17|
# +---+------+------+----------+

# %%
df.union(df1).count()
# Out:
# 13

# %%
df.createOrReplaceTempView("people")

# %%
df1.createOrReplaceTempView("people1")

# %%
spark.sql(""" select * from people union select * from people1""").show()
# Out:
# [Stage 6:===============================================>         (20 + 4) / 24]
# +---+------+------+----------+
# | id|  name|salary|manager_id|
# +---+------+------+----------+
# | 10|  Anil| 50000|        18|
# | 11| Vikas| 75000|        16|
# | 12| Nisha| 40000|        18|
# | 13| Nidhi| 60000|        17|
# | 14| Priya| 80000|        18|
# | 15| Mohit| 45000|        18|
# | 16|Rajesh| 90000|        10|
# | 17| Raman| 55000|        16|
# | 18|   Sam| 65000|        17|
# | 17| Raman| 59000|        16|
# | 19| Sohan| 50000|        18|
# | 20|  Sima| 75000|        17|
# +---+------+------+----------+

# %%
spark.sql(""" select * from people union all select * from people1""").show()
# Out:
# +---+------+------+----------+
# | id|  name|salary|manager_id|
# +---+------+------+----------+
# | 10|  Anil| 50000|        18|
# | 11| Vikas| 75000|        16|
# | 12| Nisha| 40000|        18|
# | 13| Nidhi| 60000|        17|
# | 14| Priya| 80000|        18|
# | 15| Mohit| 45000|        18|
# | 16|Rajesh| 90000|        10|
# | 17| Raman| 55000|        16|
# | 18|   Sam| 65000|        17|
# | 17| Raman| 55000|        16|
# | 17| Raman| 59000|        16|
# | 19| Sohan| 50000|        18|
# | 20|  Sima| 75000|        17|
# +---+------+------+----------+

# %%
spark.sql(""" select * from people union select * from people1""").count()
# Out:
# 12

# %%
spark.sql(""" select * from people union all select * from people1""").count()
# Out:
# 13

# %%
spark.stop()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 spark.stop()
#
# NameError: name 'spark' is not defined
