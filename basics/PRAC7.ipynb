# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import os

# %%
spark = SparkSession.builder\
    .appName("Practice")\
    .master("local[*]")\
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/29 16:51:42 WARN Utils: Your hostname, Somnath, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/01/29 16:51:42 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/29 16:51:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# READ MODE

# %%
file_path = "/home/somnath/my_vscode_project/input_data/MOCK_DATA.csv"
path = "/home/somnath/my_vscode_project/output_data/"

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .option("mode", "PERMISSIVE") \
    .option("inferSchema", "true") \
    .load(file_path)

# %% [markdown]
# WRITE MODE with repartition

# %%
df.repartition(1).write.format("CSV") \
    .option("header", "true") \
    .mode("overwrite") \
    .save(path)

# %%
os.listdir(path)
# Out:
# ['_SUCCESS',
#  'part-00000-f2d2aa02-c6ee-4d26-979c-2f7773006684-c000.csv',
#  '._SUCCESS.crc',
#  '.part-00000-f2d2aa02-c6ee-4d26-979c-2f7773006684-c000.csv.crc']

# %%
spark.stop()
