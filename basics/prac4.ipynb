# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
import os

# %%
spark = SparkSession.builder \
    .appName("Handle Corrupted Records") \
    .master("local[*]") \
    .getOrCreate()

# %%
file_path = "/home/somnath/my_vscode_project/input_data/iris2.json"

# %%
spark.read.format("json").option("inferSchema", "true").option("multiline", "true").option("mode", "PERMISSIVE").load(file_path).show(truncate=False)
# Out:
# +-----------+----------+-----------+----------+-------+
# |petalLength|petalWidth|sepalLength|sepalWidth|species|
# +-----------+----------+-----------+----------+-------+
# |1.4        |0.2       |5.1        |3.5       |setosa |
# |1.4        |0.2       |4.9        |3.0       |setosa |
# |1.3        |0.2       |4.7        |3.2       |setosa |
# |1.5        |0.2       |4.6        |3.1       |setosa |
# |1.4        |0.2       |5.0        |3.6       |setosa |
# |1.7        |0.4       |5.4        |3.9       |setosa |
# |1.4        |0.3       |4.6        |3.4       |setosa |
# |1.5        |0.2       |5.0        |3.4       |setosa |
# |1.4        |0.2       |4.4        |2.9       |setosa |
# |1.5        |0.1       |4.9        |3.1       |setosa |
# |1.5        |0.2       |5.4        |3.7       |setosa |
# |1.6        |0.2       |4.8        |3.4       |setosa |
# |1.4        |0.1       |4.8        |3.0       |setosa |
# |1.1        |0.1       |4.3        |3.0       |setosa |
# ...

# %%
spark.stop()
