# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import os

# %%
spark = SparkSession.builder\
    .appName("Practice")\
    .master("local[*]")\
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/23 14:07:44 WARN Utils: Your hostname, Somnath, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/01/23 14:07:44 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/23 14:07:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
file_path = "/home/somnath/my_vscode_project/input_data/ipl.csv"

# %%
df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .option("inferSchema", "false") \
    .option("mode", "FAILFAST") \
    .load(file_path)

# %%
df.show(5)
df.printSchema()
spark.stop()
# Out:
# +--------------------+--------------------+----------+--------------------+-------------+--------------------+---------------+--------------------+----------+--------------------+--------------------+------+------------+----------+-------+-------------+-----------+------------+----------+
# |               team1|               team2|match_date|         toss_winner|toss_decision|              winner|player_of_match|               venue|      city|       team1_players|       team2_players|season|match_number|match_type| result|result_margin|target_runs|target_overs|super_over|
# +--------------------+--------------------+----------+--------------------+-------------+--------------------+---------------+--------------------+----------+--------------------+--------------------+------+------------+----------+-------+-------------+-----------+------------+----------+
# |Royal Challengers...|Kolkata Knight Ri...|2008-04-18|Royal Challengers...|        field|Kolkata Knight Ri...|    BB McCullum|M Chinnaswamy Sta...| Bangalore|R Dravid, W Jaffe...|SC Ganguly, BB Mc...|     1|           1|    League|   runs|        140.0|      223.0|        20.0|         N|
# |     Kings XI Punjab| Chennai Super Kings|2008-04-19| Chennai Super Kings|          bat| Chennai Super Kings|     MEK Hussey|Punjab Cricket As...|Chandigarh|K Goel, JR Hopes,...|PA Patel, ML Hayd...|     1|           2|    League|   runs|         33.0|      241.0|        20.0|         N|
# |    Delhi Daredevils|    Rajasthan Royals|2008-04-19|    Rajasthan Royals|          bat|    Delhi Daredevils|    MF Maharoof|    Feroz Shah Kotla|     Delhi|G Gambhir, V Sehw...|T Kohli, YK Patha...|     1|           3|    League|wickets|          9.0|      130.0|        20.0|         N|
# |      Mumbai Indians|Royal Challengers...|2008-04-20|      Mumbai Indians|          bat|Royal Challengers...|     MV Boucher|    Wankhede Stadium|    Mumbai|L Ronchi, ST Jaya...|S Chanderpaul, R ...|     1|           4|    League|wickets|          5.0|      166.0|        20.0|         N|
# |Kolkata Knight Ri...|     Deccan Chargers|2008-04-20|     Deccan Chargers|          bat|Kolkata Knight Ri...|      DJ Hussey|        Eden Gardens|   Kolkata|WP Saha, BB McCul...|AC Gilchrist, Y V...|     1|           5|    League|wickets|          5.0|      111.0|        20.0|         N|
# +--------------------+--------------------+----------+--------------------+-------------+--------------------+---------------+--------------------+----------+--------------------+--------------------+------+------------+----------+-------+-------------+-----------+------------+----------+
# only showing top 5 rows
# root
#  |-- team1: string (nullable = true)
#  |-- team2: string (nullable = true)
#  |-- match_date: string (nullable = true)
#  |-- toss_winner: string (nullable = true)
#  |-- toss_decision: string (nullable = true)
#  |-- winner: string (nullable = true)
#  |-- player_of_match: string (nullable = true)
#  |-- venue: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- team1_players: string (nullable = true)
#  |-- team2_players: string (nullable = true)
#  |-- season: string (nullable = true)
#  |-- match_number: string (nullable = true)
#  |-- match_type: string (nullable = true)
#  |-- result: string (nullable = true)
#  |-- result_margin: string (nullable = true)
#  |-- target_runs: string (nullable = true)
#  |-- target_overs: string (nullable = true)
#  |-- super_over: string (nullable = true)
